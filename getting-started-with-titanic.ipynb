# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# %%
# data
train_data = pd.read_excel("train.xlsx")
display(train_data.head())
test_data = pd.read_csv("test.csv")
display(test_data.head())
# Out:
#    PassengerId  Survived  Pclass                          Name   Sex   Age  \
# 0          546         0       1  Nicholson, Mr. Arthur Ernest  male  64.0
# 1           75         1       3                 Bing, Mr. Lee  male  32.0
# 2          510         1       3                Lang, Mr. Fang  male  26.0
# 3          644         1       3               Foo, Mr. Choong  male   NaN
# 4          873         0       1      Carlsson, Mr. Frans Olof  male  33.0
#
#    SibSp  Parch Ticket     Fare        Cabin Embarked
# 0      0      0    693  26.0000          NaN        S
# 1      0      0   1601  56.4958          NaN        S
# 2      0      0   1601  56.4958          NaN        S
# 3      0      0   1601  56.4958          NaN        S
# 4      0      0    695   5.0000  B51 B53 B55        S
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# ...

# %%
# test to see if gender has a strong correlation with survival

women = train_data.loc[train_data.Sex == 'female']["Survived"]
rate_women = sum(women)/len(women)
print(f"Percentage of women who survived: {round(rate_women,2)}%")

men = train_data.loc[train_data.Sex == 'male']["Survived"]
rate_men = sum(men)/len(men)
print(f"Percentage of men who survived: {round(rate_men, 2)}%")
# Out:
# Percentage of women who survived: 0.74%
# Percentage of men who survived: 0.19%

# %%
from sklearn.ensemble import RandomForestClassifier

y = train_data["Survived"]

features = ["Pclass", "Sex", "SibSp", "Parch"]
X = pd.get_dummies(train_data[features]) # one hot encoding all features
X_test = pd.get_dummies(test_data[features]) # one hot encoding all features

model = RandomForestClassifier(n_estimators=100, max_depth=5, random_state=1)
model.fit(X, y)
predictions = model.predict(X_test)

output = pd.DataFrame({'PassengerId': test_data.PassengerId, 'Survived': predictions})
# output.to_csv('submission.csv', index=False)
display(output)
# Out:
#      PassengerId  Survived
# 0            892         0
# 1            893         1
# 2            894         0
# 3            895         0
# 4            896         1
# ..           ...       ...
# 413         1305         0
# 414         1306         1
# 415         1307         0
# 416         1308         0
# 417         1309         0
#
# [418 rows x 2 columns]
